# %%
# 스캔 폴더에 폴더가 아닌 파일이 있는 경우 오류 제거
# 저장될 경로에 이미 똑같은 이름의 파일이 있는 경우 더 큰 용량으로 대체

# %%
import tkinter as tk
from tkinter import filedialog
import os
import shutil

# %%
def Count_Folders(self):
    folder_list = Read_Files(self, self.songs_location)
    self.instruction.config(text = "안내: 검색된 폴더 개수는 {}개 입니다.".format(len(folder_list)))

def Read_Files(self, dir):
    file_list = os.listdir(dir)
    return file_list

def Ask_Directory(self):
    dirName = filedialog.askdirectory()
    return dirName

def Activate_Extract_Button_Condition_Check(self):
    print("체크중")
    if self.songs_location != "" and self.extract_location != "":
        self.extract_start_btn.config(state = 'active')
        Count_Folders(self)  # 폴더 개수 세고, instruction label에 설명 해주기.
        print("버튼활성화")
    else:
        self.extract_start_btn.config(state = 'disabled')
        self.instruction.config(text = "안내: Songs 경로와 노래가 저장될 경로를 선택해주세요.") 
        print("버튼비활성화")


class SampleApp(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        
        self.title('Extract Osu Songs')              # 창 제목 설정
        self.geometry("500x250+250+700")   # 창 크기 (너비x높이+x좌표+y좌표)
        self.resizable(False, False)   # 창 크기 조절 여부        
        
        self._frame = None
        self.switch_frame(StartPage)

    def switch_frame(self, frame_class):
        new_frame = frame_class(self)
        if self._frame is not None:
            self._frame.destroy()
        self._frame = new_frame
        self._frame.pack()


class StartPage(tk.Frame):  

    def Select_Songs_Location(self):
        self.songs_location = Ask_Directory(self)
        self.songs_location_show.config(text="Songs Location : " + self.songs_location)
        Activate_Extract_Button_Condition_Check(self)

    def Select_Extract_Location(self):
        self.extract_location = Ask_Directory(self)
        self.extract_location_show.config(text="Extract Location : " + self.extract_location)
        Activate_Extract_Button_Condition_Check(self)

    def Extract_Start(self):
        print("시작")
        folder_list = Read_Files(self, self.songs_location) 

        for i in folder_list:
            try:
                inside_folder_location = self.songs_location + "/" + i  
                inside_files = Read_Files(self, inside_folder_location) # 폴더 내부의 모든 파일 이름을 스캔
                # print(inside_files)
                # print(inside_folder_location)
                # print(self.extract_location)

                if inside_folder_location == self.extract_location:
                    print(i)
                    print("여긴 출력될 폴더인걸?\n")
                    continue

                collect_music_files = [] # 이 리스트에 음악 확장자인 녀석의 이름을 담는다.
                for j in inside_files:
                    if j[-3:] == "mp3" or j[-3:] == "MP3" or j[-3:] == "ogg" or j[-3:] =="wav" or j[-3:] == "flac":
                        # print("끝자리가" + j[-3:] + "라서 추가했다.")
                        collect_music_files.append(j)
                # print("뮤직 파일은 누구?", collect_music_files) 

                if len(collect_music_files) >= 2:
                    file_sizes = []
                    for k in collect_music_files: # 뮤직 확장자인 녀석이 다수일 수도 있기때문에 그 중 가장 용량이 큰 녀석만 복사
                        file_sizes.append(os.path.getsize(self.songs_location + "/" + i + "/" + k))
                    # print("뮤직 파일들의 용량들은 몇?", file_sizes)
                    # print("그 중 가장 용량이 큰 애는 몇?", max(file_sizes))
                    greatest_size_file = collect_music_files[file_sizes.index(max(file_sizes))]
                    # print("그 중 가장 큰 애는 누구?", greatest_size_file)
                    the_file_to_be_copied = greatest_size_file
                elif len(collect_music_files) == 0:
                    print(i)
                    print("너는 음악파일이 없네?\n")
                    continue
                else:
                    # print("너는 혼자구나")
                    the_file_to_be_copied = collect_music_files[0]

                the_file_to_be_copied_location = self.songs_location + "/" + i + "/" + the_file_to_be_copied    
                extension_name = the_file_to_be_copied[-4:]            
                new_file_name = i.split()
                del new_file_name[0]
                new_file_name = ' '.join(new_file_name)
                new_file_name = new_file_name + extension_name
                # print(new_file_name)
                new_file_directory = self.extract_location + "/" + new_file_name
                # print(new_file_directory)
                old_file_directory = self.extract_location + "/" + the_file_to_be_copied 
                # print(old_file_directory)

                if os.path.isfile(new_file_directory): # 저장하려는 곳에 이미 똑같은 이름의 파일이 있는경우                 
                    print(i)
                    if os.path.getsize(the_file_to_be_copied_location) > os.path.getsize(new_file_directory): # 두 개의 용량비교 해서 큰 쪽꺼를 가져온다.
                        os.remove(new_file_directory)
                        shutil.copy2(the_file_to_be_copied_location, self.extract_location) # 카피 실행
                        os.rename(old_file_directory, new_file_directory) # 이름변경 실행
                        print("이미 있는 녀석이지만 큰 용량의 것을 가져왔다.")
                    else:
                        print("이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.\n")
                        continue
                else:                        
                    shutil.copy2(the_file_to_be_copied_location, self.extract_location) # 카피 실행
                    # print(the_file_to_be_copied_location + "파일을" + self.extract_location + "로 카피했습니다.")
                    os.rename(old_file_directory, new_file_directory) # 이름변경 실행
                    # print("새로운 파일의 이름은 " + new_file_name + " 입니다.")
                print("\n")
            except NotADirectoryError:
                print(i)
                print("이 친구는 폴더가 아니라 그냥 파일이네.\n")
                continue

        print("복사 완료")

    def __init__(self, master):  
        tk.Frame.__init__(self, master)
        tk.Frame.configure(self, width = 500, height = 250)

        # Songs 위치, 저장 위치 초기화  
        self.songs_location = ""
        self.extract_location = ""

        #위에서부터 위젯 위치 순서대로 나열

        self.instruction = tk.Label(self, text = "안내: Songs 경로와 노래가 저장될 경로를 선택해주세요.") 
        self.instruction.place(x=25, y=15)
        
        self.songs_location_btn = tk.Button(self, text = 'Songs 경로 선택', anchor = 'center', command = self.Select_Songs_Location)
        self.songs_location_btn.place(x=25, y=50)    

        self.songs_location_show = tk.Label(self, text = "Songs Location :") 
        self.songs_location_show.place(x=25, y=80)
        
        self.extract_location_btn = tk.Button(self, text = '추출될 경로 선택', anchor = 'center', command = self.Select_Extract_Location)
        self.extract_location_btn.place(x=25, y=110)  

        self.extract_location_show = tk.Label(self, text = "Extract Location :")
        self.extract_location_show.place(x=25, y=140)

        self.extract_start_btn = tk.Button(self, text = '추출 시작', anchor = 'center', state = 'disabled', command = self.Extract_Start)
        self.extract_start_btn.place(x=25, y=195)  


if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()
# Out:
# 체크중
# 버튼비활성화
# 체크중
# 버튼활성화
# 시작
# 1000335 Hibiki Sakura & Naruzo Machio (CV_ Fairouz Ai & Kaito Ishikawa) - Onegai Muscle
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1000722 Ohara Yuiko - Zero Centimeters (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1000722 Ohara Yuiko - Zero Centimeters (TV Size) (2)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1000972 Yorushika - Hole In The Heart
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1001327 HyuN - Disorder
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1001507 ZUTOMAYO - Kan Saete Kuyashiiwa
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1001546 Carpool Tunnel - Afterlight
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1001794 Phantom Sage - Holystone
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1002819 Roselia - MIIRO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1002819 Roselia - MIIRO (2)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1002903 wa - Black Lotus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1003093 Hibiki Sakura (CV- Fairouz Ai) & Naruzo Machio (CV- Ishikawa Kaito) - Onegai Muscle
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1003217 nekodex - circles!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1003554 yuki - Nadeshiko Sensation
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1004088 Pecorine (CV_ MAO), Kokkoro (CV_ Itou Miku), Karyl (CV_ Tachibana Rika)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1004416 -namirin - Kanzen Shouri-Esper Girl
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 100501 Tamura Yukari - Fantastic future (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1005468 Yunomi - Game Over (feat TORIENA)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1005492 M2U - Promise (feat Sherie)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1006502 Maeda Jun - Natsukage
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1008355 nano feat MY FIRST STORY - SAVIOR OF SONG -An Remix-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1008419 BilliumMoto - Four Veiled Stars
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1009907 James Landino & Kabuki - Birdsong
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1010164 goreshit - one way to hannover
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1011011 nekodex - new beginnings
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1011337 Camellia - Beyond the Geostationary Orbit Level
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1011671 Hirasawa Ui (CV_ Yonezawa Madoka) - Oui! Ai Kotoba
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1012337 Frums (unknown -lambda-) - 19ZZ
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1012337 Frums (unknown lambda) - 19ZZ
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1012634 Maverick - Shironaga Star Jet -aquamarine mix-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1013140 Chitose Sara - Merry Merry Go Round
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1013400 Nekomata Gekidan - AsiaN distractive
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1013935 Laur - Vindication
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1014611 Shimotsuki Haruka - un secret
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1014868 PSYQUI - Update
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1015169 Thaehan - Insert Coin
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1015320 VA - BangDream Project A
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1017088 YUC'e - Chemical Cookie
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1017701 IAHN - Feel It
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1018454 Fractal Dreamers - Celestial Horizon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1018637 Yorushika - That's Why I Gave Up on Music
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1019836 Kamiyama Yoh - YELLOW
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1020289 Yorushika - Ai Jijo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1020444 Machico - Million Smile (Short Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1021536 t+pazolite - You are the Miserable (Uncut Edition)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1022130 REDALiCE & aran - Sweet Requiem
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1022394 eufonius - Kimi ni Aeta kara
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1023425 Frums - Pictured as Perfect and Plus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1023679 Camellia - LET'S JUMP
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1024053 Baby's breath - Kusabi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1024827 Roselia - BRAVE JEWEL (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1025170 Frums - We Want To Run
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 102519 KOTOKO - unfinished (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1025679 i_o - Possession
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1025944 Johnny Berglund - Angry Nu Metal Trailer No3
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1026168 Ta9-5 - Positive (feat Looci)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1026319 Camellia - Artificial Snow
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1026511 Amatsuki - dakara boku wa ongaku wo yameta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1026602 Chino (CV- Minase Inori) - Mirai Puzzle
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1026824 BlackY - Mirrorwall
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1027467 Camellia - Syzygia
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1027707 M2U - Rising Star
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1029053 RADWIMPS - Grand Escape (Movie Edit) [feat Touko Miura]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1029946 Taishi - All For The Time
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1030201 Camellia - Jingle (Metal Arrange - Cover)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1030201 Camellia - Jingle (Metal Arrange _ Cover)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1030814 coldrain - MAYDAY (feat Ryo from Crystal Lake)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1031458 MHGU - Zinogre Theme
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1031483 Monster Hunter World - Tigrex Theme
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1031560 EGOIST - Namae no Nai Kaibutsu (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1031812 Numtack05 - Ikari
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1031862 Feryquitous - Vend
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1031877 lapix - You're Beautiful
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1032027 BUTAOTOME - Kurukuru Tsukai
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1032093 Go Shiina feat Nami Nakagawa - Kamado Tanjirou no Uta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1032511 Hino Isuka - #be_fortunate
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1032553 Aiobahn - Sugiyuku Hi to Kimi e (feat nayuta)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1034542 Senko (CV- Waki Azumi) - Moffumofu DE Yoi no Ja yo (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1034542 Senko (CV_ Waki Azumi) - Moffumofu DE Yoi no Ja yo (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1034608 Pastel-Palettes - Harumodoki (Asterisk DnB Remix) [Rakakun- Edit]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1035145 Diao Ye Zong feat nayuta - Tori yo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 103550 Leon Lai - Zhong Ai Qing You (Speed up Version)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1035777 Mahora Gakuen Chuutoubu 2-A Kanakanagumi - Kagayaku Kimi e (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1036157 Kiryu - Q
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1037092 HoneyWorks feat Kotoha - Ai ni Deai Koi wa Tsuzuku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1037591 May'n - graphite_diamond (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1038186 Yorushika - Parade
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1038191 Hino Honoka - Intersect World
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 103856 fripSide - fortissimo -the ultimate crisis-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1039296 Murata Ayumi - Drawing Again
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1040265 MAXIMUM THE HORMONE - Zetsubou Billy (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 104030 Ushirokara Haiyoritai G - Koi wa Chaos no Shimobenari (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1040433 amazarashi - Maegaki
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1041146 Camellia vs Akira Complex - Railgun Roulette
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1041437 Capi - Watashi, Idol Sengen
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 104151 Anamanaguchi - STILL SPLODIN' THO (Interlude)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1041518 Hatsuki Yura - Halloween of the Dead
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1041849 RADWIMPS - Tenki no Ko Series Pack
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1041915 KANA-BOON - Nai Mono Nedari
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1042140 Asami Yuuko - Yume, Hitohira (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1042161 Hatsuki Yura - Izayoi Warabeuta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1042985 TRUE - Hiryuu no Kishi (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1043170 PSYQUI feat mikanzil - Bye or not
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1043685 TROISANGES - CrescHeart
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1044175 John Legend - All of Me
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1044511 ASAKA - Yosakura Fubuki
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1044881 cYsmix - Classic Pursuit
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1045974 Minase Inori - harmony ribbon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1046084 Tomita Miyu - Present Moment (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1047505 cosMo@bousouP - Oceanus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1048385 Feint - We Won't Be Alone (feat Laura Brehm)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 104839 fripSide - fortissimo-from insanity affection- (Short Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 104855 nam goo min - second run
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1049099 SLASHSTREET BOYS - I'LL KILL YOU THAT WAY
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1049327 NIVIRO - The Return
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1049356 Study - Can now, Can now (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1049362 uma vs Morimori Atsushi - GLORY-ROAD
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1049506 Michael Jackson - Thriller
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1050419 Tomatsu Haruka - Resolution (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1050479 Tomatsu Haruka - Resolution (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1050560 BLUE ENCOUNT - Polaris (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1051745 UNISON SQUARE GARDEN - Phantom Joke (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 105186 Baauer - Harlem Shake
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1053469 Sweetches - Sweet Witches' Night _Rokuninme wa Daare_ (M@STER VERSION)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1054019 Jay Chou - Won't Cry
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1054045 a_hisa - Alexithymia _ Lupinus _ Tokei no Heya to Seishin Sekai
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1055375 Native Construct - Come Hell or High Water
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1055424 Camellia - Embracing intelligences
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1057234 VA - 100 Anime Songs in 30 Mins (Piano Medley)
# 너는 음악파일이 없네?
#
# 1058621 TrioStaR x Lilyca- - Floating Garden
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1058797 Petit Rabbit's - Daydream cafe (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1060064 AAAA - Hazukashigariya no Toy Soldier
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 106040 Aoi Eir - INNOCENCE (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1061110 Umeboshi Chazuke vs Morimori Atsushi - Pico-2 Funkoter-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 106212 LeaF - MEPHISTO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1064967 Yanagida Ethnica - For You the Bellz Toll
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1066763 Sayuri - Koukai no Uta (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 106740 Dormir - Sayonara Trip
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1067499 Ricky Montgomery - This December
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 106856 Paraoka Feat Iku Akume - Chaosmaid
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1069336 Endorfin - M-routine
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1069426 Billain & Vorso - Transhumanist
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 107009 Shouta Kageyama - Relic Song
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1074919 Poppin'Party - BandDream Poppin'Party pack
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1075509 Survive Said The Prophet - MUKANJYO (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1075954 fourfolium - Hosshii no!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1076218 Yamamoto Mineko - Rinne
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 107781 Suzaku - Anisakis -somatic mutation type -Forza--
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 107796 yoshiki-lisa - Destin Histoire (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1079712 Panda Eyes & Teminite - Highscore
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 108035 DJ Okawari - Flower Dance
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1080799 Kikuo - Gangu Kyou Sou Kyoku -Shuuen-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1080892 Fractal Dreamers - Gardens Under A Spring Sky
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1081573 Juliet Persia (CV- Kayano Ai) - Hush, Little Baby - Persia
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1082090 Yuyoyuppe - Hope
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1083155 CINDERELLA GIRLS!! - Onegai! Cinderella (M@STER VERSION)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1083257 Rem(CV_Minase Inori) - Wishing
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1083536 Stereo Cube - Destination Moon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 108577 fripSide - eternal reality - TV size -
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1086666 Silentroom - NULCTRL EX
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 108708 D_VOR - dEKA
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1087685 IOSYS - Cirno no Perfect Sansuu Kyoushitsu (sawawa Shissou Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1088476 xi - Solar Storm
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1090167 Chito (CV- Minase Inori), Yuuri (CV- Kubo Yurika) - Ugoku, Ugoku (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1091179 UNDEAD CORPORATION - Sunny Miracle no Benigiri Ihen
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1092856 F-777 - Viking Arena
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 109438 TJHangneil - Kamui
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1096683 Fractal Dreamers - Ad Astra
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1098415 TrySail - Gomakashi (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1098578 Camellia - POWA OF DA WILDANES
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1099840 fourfolium - Gugutto Work- (Short Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1100732 Amamiya Sora - PARADOX (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1102973 Station Earth - Cold Green Eyes feat Roos Denayer
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1103372 Tomita Miyu, Onishi Saori, Ohzora Naomi, Hanazawa Kana - Hallelujah-Essaim (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1103826 Station Earth - Summer Soulstice
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1105147 Hoshino Gen - Sapiens
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 110522 HTT - U&I (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 110547 seleP - Remember Me
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 110637 Pendulum - The Island (MaxNRG Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1107159 Fractal Dreamers - Module_410
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1107384 technoplanet - Fly Like You
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1108327 Amateras Records - Guuzou Distortion
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1108353 Kano - Hikari no Michishirube (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1112418 Jackal Queenston - Rubber Band
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1112559 siqlo - Purple Hyacinth feat Norico
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1112714 KOAN Sound & Asa - Tetsuo's Redemption (Billain Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1114402 Frums - We Want To Run
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1114900 void - Sun Goes Down (BMS edit)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1114940 Kola Kid - sea shells
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1115875 Sako Tomohisa - Getta Banban (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1116952 Kola Kid - broken legs
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1120648 WAVAV - Double Agent
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1120790 Thaehan - Bwa !
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1121784 Hoshino Gen - DORAEMON
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1121860 ZUTOMAYO - Kan Saete Kuyashiiwa
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1121995 Junjou no Afilia - Kyuukyoku Unbalance! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1122944 Frums - Nisemono
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1123154 ARForest - Metheus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1125991 Noisia - Running Blind
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1126085 Dungeon and Fighter - DNF-Windy warrior
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1126358 Aiobahn - Sugiyuku Hi to Kimi e (feat nayuta)
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 112675 Pet na Kanojotachi - Kimi ga Yume wo Tsuretekita (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1127956 Coconatsu - Hare Tokidoki Melancholic
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 112898 ICE - L (Blue)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1129465 Shalltear Megumin Rem Visja - Ponkottsu! Isekai Theater by Shalltear Megumin Rem Visja
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1129916 Plasmagica - Have a Nice MUSIC!! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1131640 HyuN feat YURI - Disorder
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 113175 Falcom Sound Team JDK - Phantasmagoria
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 113273 HTT - Gohan wa Okazu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 113283 Ryu- - I'm so Happy
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1135136 HyuN - Grin _ Full Ver
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1137583 O2i3 - TSLove
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1139118 Nanao Akari - Instant Heaven (featEve)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1139247 O2i3 - Heart Function
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 114156 P-Light - TRIGGER-HAPPY
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 114488 Gentle Stick X M2U - Hades in the Heaven
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1145160 halca - Toki toshite Violence (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 114599 yuikonnu - Souzou Forest
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 114750 Lin-G - I Want You
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1150271 HyuN - Soulwind
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1153537 Nanao Akari - Turing Love (feat Sou) (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1156356 Dareharu - Karma
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1157020 Nakagawa Shouko - Sorairo Days
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 115715 fripSide - future gazer (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1159036 LiSA - Gurenge
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1160923 Haruka Fukuhara - Kaze ni Fukarete
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 116133 REDALiCE - Kizuato
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1161442 Yorushika - Yuunagi, Bou, Hana Madoi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1162320 Ai Otsuka - Sakuranbo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1174746 xi - Titania
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 117547 Otome Shintou - 2 Gakki Debut Daisakusen!!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1175854 Roselia - Hidamari Rhodonite(7th LIVE)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 117757 keeno - glow
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 117791 KOTOKO - WING OF ZERO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 118227 Darren Korb - Terminal March
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 118383 iconoclasm - Zirkfied
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1186788 Machico - 1 Milli Symphony
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1187139 Pecorine (CV_ MAO), Kokkoro (CV_ Itou Miku), Karyl (CV_ Tachibana Rika) - Lost Pri
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 118763 Team-SASAKURATION - AVALON
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 118959 SHK - Milky Way
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 118965 xi - Sedap Malam
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1192653 Suzuki Konomi - Realize (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1193338 Yama - Haru wo tsugeru
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 119359 kors k - smooooch
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1199076 HyuN - Grin
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1202073 Kenshi Yonezu - Orion
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 120289 Dj Mashiro - Prismatic Lollipops
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 120379 supercell - Kimi no Shiranai Monogatari (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1204419 the peggies - Centimeter (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1204733 Fujita Akane, Miyamoto Yume, Ozawa Ari - Precious You_ (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1207300 halca - Kokuhaku Bungee Jump (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 120737 Misawa Sachika - Links (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1207980 IOSYS feat 3L - Miracle Hinacle -Euro Beat Remix-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 120838 Ryu- - We're so Happy
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1210900 ZUTOMAYO - STUDY ME
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1211012 YOASOBI - Yoru ni Kakeru
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1213465 MY FIRST STORY feat chelly (EGOIST) - 1,000,000 TIMES
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1213615 YOASOBI - Ano Yume wo Nazotte
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 121542 earthmind - ARCADIA
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1216541 Afilia Saga - SML (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1217129 Pecorine (CV_ MAO), Kokkoro (CV_ Itou Miku), Karyl (CV_ Tachibana Rika) -
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1220489 ReoNa - ANIMA (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1227003 YOASOBI - Ano Yume o Nazotte
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 122745 Ruby Tuesday - Stay with me
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1230867 YOASOBI - Yoru ni Kakeru
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1231946 the peggies - Centimeter
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 123431 BlackY - Max Burning!!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 123456 Lite Show Magic - Crack traxxxx
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1241442 ZUTOMAYO - Milabo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1245882 Chieru (CV_ Sakura Ayane), Kuroe (CV_ Tanezaki Atsumi), Yuni (CV_ Kohara
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 124866 DJ YOSHITAKA - VALLIS-NERIA
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 124867 SOUND HOLIC feat Nana Takahashi - Ha lle lu jah
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 125464 Deuce - Senretsu no ryu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1256369 YOASOBI - Genjou
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 125785 Y&Co - POODLE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 125856 P-Light - TRIGGER-HAPPY
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 125877 Sana - Terekakushi Shishunki
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 126132 IOSYS - Cirno's Perfect Math Class
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1262194 Dead - Motteke Sailor Fuku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 126508 Otokaze - amamichi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 126583 nano feat MY FIRST STORY - SAVIOR OF SONG (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 126752 Yun-chi - Your song-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 127305 SSH - Intersect Thunderbolt-Remix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1273051 YOASOBI - Tabun
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1276702 Eve - Kaikai Kitan (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 127789 Mimori Suzuko - Univer Page (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1286422 YOASOBI - Halzion
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 128855 Loos - Koi Yomi Zakura
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1290309 YOASOBI - Ano Yume o Nazotte
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 129127 Suzuki Konomi - DAYS of DASH (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 129356 Ryu- - bloomin' feeling
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 129383 Harada Hitomi, Kayano Ai & Ogura Yui - Maware! Setsugekka (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 129618 senya - Though the Scent Lingers, the Flower Scattered
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 130464 Zeami - Music Revolver
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 130543 fripSide - sister's noise (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 130556 Jeff Williams - This Will Be the Day (feat Casey Lee Williams)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1320263 Various Artists - 4+6K Pack 1
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 132118 sasakureUK - Atropos (Short Edit)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1322974 Shinsei Kamattechan - My War
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1327589 YOASOBI - Ano Yume o Nazotte
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 132824 Masayoshi Minoshima - Bad Apple!! (REDALiCE Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1328863 NieN - Only For You
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 133438 Avicii ft Salem Al Fakir - You Make Me
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 133607 Suzuki Konomi - AVENGE WORLD (TV size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 134151 Hanatan - Airman ga Taosenai (SOUND HOLIC Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 134829 Seiryu - Water Horizon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 134998 REDALiCE Feat Ayumi Nomiya - Little Star
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 135412 Yuki Kajiura - Himeboshi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 135599 RAMM - Wonder Nanda- Kataomoi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1363329 YOASOBI - Kaibutsu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 136881 ETIA featJenga - Say A Vengeance
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 136889 M2U - Memory of Beach
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 136986 Lia - My Soul, Your Beats! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 137037 ESTi - HELIX
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 137197 Tomatsu Haruka - Yume Sekai (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 137586 Iguchi Yuka - Grow Slowly (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 137665 Memme - China Dress
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 138188 kors k - Insane Techniques
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1387369 YOASOBI - Halzion
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 138907 3L - Be Happy-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1390176 YOASOBI - Harujion
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 139045 Sharlo - Vidro Moyou
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 139141 Pinocchio-P - Weekly Shonen Bye-Bye
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 140097 Camellia - Bangin' Burst
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 140099 Sergey Eybog - Everlasting Summer
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 140179 TMRevolution - HOT LIMIT
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 140189 xi - Zephyros
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 140230 Dj Trio - Run Go Run
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 140257 livetune - Light Song
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 141050 fripSide - HesitationSnow
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 141360 ONE OK ROCK - Re-make
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 141360 ONE OK ROCK - Re_make
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 141386 Ayane - Complex Image
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 141415 yanaginagi - Mitsuba no Musubime (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1414338 Who-ya Extended - VIVID VICE (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 1422393 Okano akihito - Hikariare (TV size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 142382 Chihara Minori - Kyoukai no Kanata (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 142419 M2U feat Guriri - Magnolia
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 142600 Owl City - Shooting Star
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 142674 ZAQ - Alteration
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 143082 Nomizu Iori - SAVE MY HEART (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 143807 M2U - Jump to Summer
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 144223 Nakamura Meiko - Scarlet Faith
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 144589 nano feat MY FIRST STORY - SAVIOR OF SONG (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 144699 Tamura Yukari - Himitsu no Door kara Ai ni Kite (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 144849 Tsukasa Yatoki - 2A-Attack
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 144959 SHK - Identity Part 4
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 145225 Dormir - Sayonara Trip
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 145553 REDALiCE - Acceleration
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 145573 dj TAKA meets DJ YOSHITAKA - Elemental Creation
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 146008 Ray - Nagi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 146049 P-Light - TRIGGER-HAPPY
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 146299 Ayana - freak of nature- start
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 146623 t+pazolite feat Rizna - Unlimited Spark! (remake)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 146875 Nanamori-chu - Goraku-bu - Yuriyurarararayuruyuri Daijiken (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 147152 ensou feat GUMI - COMA
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 147232 jun - KIMONO PRINCESS
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 147281 SAKURA-TRICK - Won(-3-)Chu KissMe! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 147745 Risk Junk-G - Candy Galy
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 147837 P-Light - Poppin' Shower
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 148620 dj TAKA meets DJ YOSHITAKA - Elemental Creation
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 148702 RAMM ni Haiyoru Tamao-san - Kirai na WaKe Lychee
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 148760 nano - Born to Be (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 148979 gael42 & ThomasKHII - Battements d'Ame
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 149086 Nobunaga - Shinkai Shoujo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 149131 Misawa Aki - Ashita no Sora
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 149233 Misawa Sachika - Unite (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 149561 Ray - Songs Compilation
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 150928 ALTIMA - Fight 4 Real (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 151033 dj TAKA - snow storm
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 151219 a_hisa - Fairy Dance
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 151649 NegaRen - Goin' Under
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 152065 Ras - STAGER
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 152180 DecisionS - INFINITY OVERDRIVE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 152703 Qrispy Joybox featmao - Colorful Minutes
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 152779 KOTOKO - Re-Sublimity (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153114 Jam Project - Okusenman
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153199 SHK - Couple Breaking
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153239 ALTIMA - Fight 4 Real (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153316 DJ Genericname - Dear You
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153558 Stan SB - Dead
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153853 Trident - Blue Field
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 153971 Ryu- - Second Heaven
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 154156 P-Light - Sakura Reflection (P-Light Slayer Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 154929 Cres - End Time
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 155315 Kishida Kyoudan & The Akeboshi Rockets - STRIKE THE BLOOD
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 15532 Asumi Kana feat Fujita Saki & Kitamura Eri - SOMEONE ELSE (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 155439 VK - Reverse - Parallel Universe
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 155621 Sota Fujimori - DANCE ALL NIGHT
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 155749 xi - 357 Magnum
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 155973 DJ YOSHITAKA - CUSTOM DRIVE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 156219 Ray - Rakuen PROJECT (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 156314 Ray - ebb and flow (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 156937 LAST ALLIANCE - HEKIREKI (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 157296 ELISA - Dear My Friend -Mada Minu Mirai e-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 157896 Meg & Dia - Monster (DotEXE Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 158113 Daisy x Daisy - Towa no Kizuna feat Another Infinity
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 159068 AAA - Wake up! (Anime ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 159519 ZAQ - VOICE (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 159581 anubasu-anubasu - Nemesis (pi-3's Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 159623 Kicco - Shunkan Spline
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 160570 Sasaki Sayaka - Koi Saku Mirai
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 160695 Sharlo - Sleeping Butterfly
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 160779 Zou Tian Heng - No1127
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 160914 STEREO DIVE FOUNDATION - Daisy (TV size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 160937 RO-KYU-BU! - Get goal! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 161066 Hanazawa Kana &  Itou Shizuka & Toyosaki Aki - Minna no Namae o Irete Kudasai TV size ver
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 161328 Suzuki Konomi - DAYS of DASH (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 162193 DJ YOSHITAKA featMichaela Thurlow - SUPER HERO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 162737 Remixed by DJ Command - Mermaid girl -Akiba Koubou MIX-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 163908 Nami Nakagawa - DON'T CUT
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 164299 fhana - Itsuka no, Ikutsuka no Kimi to no Sekai (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 164429 Various Artists - J-Core Mix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 165164 ChouCho - My dear friend
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 165391 Jin feat MARiA from GARNiDELiA - daze (short ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 165716 yuikonnu - Souzou Forest
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 165924 Senpi- - Touhou EX Boss Rush!! +a Kouhen
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 165991 Reol - +Danshi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 166146 NAGI - inside
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 167058 Sharlo - ebb and flow
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 167091 a_hisa - Fanatiker der Liebe
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 167880 BABYMETAL - MEGITSUNE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 168111 yanaginagi - Tokohana (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 169380 Tokisawa Nao - BRYNHILDR IN THE DARKNESS -Ver EJECTED-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 169985 Nishizawa Hagumi - Yumekai Biyori
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170144 yanaginagi - Tokohana
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170223 xi - Fiat Lux
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170327 TMRevolution x Nana Mizuki - Preserved Roses (TV-Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170412 ClariS - STEP (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170446 Nanahoshi Kangengakudan feat Hatsune Miku - Rubik's Cube
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170968 BoA - MASAYUME CHASING (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 170979 Itou Kanako - Skyclad no Kansokusha Short Ver
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 171090 myon - G Free ~ Final Dream
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 171480 fripSide - black bullet
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 171841 DragonForce - Heroes of Our Time
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 171880 xi - Happy End of the World
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 172228 DJAmuro Remixed by DM ASHURA - AAA
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 172867 Ryu- - Plan 8
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 172907 yanaginagi - Tokohana (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 172908 P4koo - Platina Disco (P4koo remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 173010 7!! - Bye Bye (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 173078 Nakamura Meiko - Across the Destiny
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 173152 Tokisawa Nao - Analyze
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 173612 xi - FREEDOM DiVE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 173805 Kon Natsumi - Niji no Kakera-TV size ver-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 174304 Hashimoto Miyuki - Salutsoleil!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 174381 Yuyoyuppe - AiAe
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 174526 KOTOKO - Shichitenhakki-Shijou Shugi!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 174550 orangentle _ Yu_Asahina - HAELEQUIN
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 175684 Neru - Lost One no Goukoku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 176066 Taneda Risa, Suzaki Aya, Ichimichi Mao, Tadokoro Azusa - Ichiban Boshi (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 176446 High Speed Music Team Sharpnel - MAMA
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 176813 Minamotoya - Ray
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 176972 Sawano Hiroyuki - Blowin'
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 177155 Junk - Qualia
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 177856 Nhato - Magic
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 178018 Senpi- - The First Part of Touhou EX Boss Rush!!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 178027 Halozy - Starry Presto
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 178426 XeoN - Thor ~ Deepin' Absonant Mix ~
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 178826 sweet ARMS - Trust in you (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 179856 Blackmill - Home (Full Version)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 179951 fripSide - black bullet
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 179991 Jeff Williams & Casey Lee Williams - This Will Be the Day (James Landino's M
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 180632 angela - ANGEL
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 180701 TeamNekokan[Neko] featuringAmaoto Junka - tsunagukizuna
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 180812 Sporty-O - Let Me Hit It
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 180923 Rita - Little Busters! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 182221 Rabpit - Saika
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 183161 u's - Snow halation (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 183261 nomico - Hoshizora e Kakaru Hashi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 183272 Ryu- - Sakura Mirage
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 183478 Azu - Haryu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 183878 Sota Fujimori - VOLTEXES II
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 183949 The Living Tombstone - Nippontradamus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 184023 Hyadain - Enemy Appearance!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 184097 Rex - Heart of Witch
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 184667 Itou Kanako - Hacking to the Gate (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 185362 ETIA - Nihonshiki Koukaku-OukaRanman-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
#
#
# 185800 yanaginagi - mnemonic
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 186096 Qrispy Joybox - snow prism
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 186159 senya - Utakata, Ai no Mahoroba
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 186336 Hashimoto Miyuki - UN-DELAYED -TVsize-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 186465 Marika - Soul Release short ver
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 187154 Ryu- Vs Sota - Go Beyond!!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 187538 Jin ft MARiA from GARNiDELiA - daze (short ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 188056 YUZU - Hyori Ittai
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 189224 DJ Sharpnel - Over the Fullereneshift
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 189643 Mayumi Morinaga(moimoi) - dreamin' featRyu-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 189927 Niira Etsuko - Imaginary Waltz
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 189938 NieN - You & Me
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 190529 Junk - Aihana (Love+ Edit)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 190954 Aoi Eir - IGNITE (TV size ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 191164 3L - Endless night
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 192018 fhana - divine intervention (TV SIZE)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 192569 Haruna Luna - Startear -TV size ver-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 193326 Matsunaga Maho (from StylipS) - Resonant World
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 193512 Anthony Donato - The Scales of Struggle
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 193972 Paul Bazooka - SigNalize
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 194921 Amane - Space Time (Amane Hardcore Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 194923 yst - the lost dedicated
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 194955 MuryokuP - Frozen World
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 195210 Neru feat IA - Enmei Chiryou
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 195390 Yooh - Shanghai Kouchakan ~ Chinese Tea Orchid Remix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 195940 MiddleIsland - Achromat
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 196171 xxdbxx - Taekwonburi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 196172 P-Light feat mow-2 - OVERDRIVERS
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 196412 ONE OK ROCK - Answer is Near
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 197085 Kayano Ai - Oracion(TV-Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 197451 Satou Satomi & Kayano Ai - Madoromi no Yakusoku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 198160 Pile - Aishiteru Banzai! (Prepro Piano Mix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 198380 sakuzyo - Neurotoxin
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 198978 Katarzyna Laska - No Ordinary Girl
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 200552 BlackYooh vs siromaru - BLACK or WHITE-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 200945 yak_won - Lucid
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 201333 Hanatan - Shiwa
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 201476 Ayane - Endless Tears
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 201515 The Flashbulb - Passage D
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 201563 Blue123 - Caged Heart
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 201690 ESTi - ZERO FILL LOVE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 20173 Nakagawa Shouko - Namida no Tane, Egao no Hana
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 202072 Ice - Entrance (All Version)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 202610 Mili - Nine Point Eight
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 202755 GReeeeN - Shinobi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 203250 Dev-Null - Rave 7
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 203567 ClariS - Connect -TV MIX-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 203734 JerryC - Canon Rock
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 203929 Vospi - Reverence
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 204326 Nhato - Miss You
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 205036 Alex Goot, Kurt Schneider, and Chrissy Costanza - Counting Stars (Nightcore Mix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 205220 Styles & Breeze feat Karen Danzig - Heartbeatz
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 206097 Betwixt & Between - 12 little fragments of silence
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 206887 TK from Ling tosite sigure - unravel (TV edit)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 207075 Sasaki Sayaka - Distance
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 207525 Camellia - Bangin' Burst
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 207599 44teru-k remixed wa - Isetsu Higanbana Daiichi - Gensho no Amaryllis -
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 207612 u's - No brand girls
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 207949 HHH - Ignited Night
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 208095 Sharlo & yealina - Kakushigoto
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 208242 JIN - Shounen Brave
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 20871 xi - Halcyon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 208999 An - LittleGameStar
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 209682 NM featHeather Elmer - Closer to my Heart (jun remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 209952 Momobako & Aihara Kaori - Senbonzakura
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 209969 Team-Hanayamata- - Hana wa Odore ya Irohaniho(TVsize)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 210319 Igorrr - Mastication Numerique
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 210610 xi - Garyou Tensei
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 212088 Ranzor - That Was Too Slow
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 213202 Aso Natsuko - More-more LOVERS!!(TV ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 214  - Christmas Memories v3
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 214038 Rengoku Teien - Gasei Sozai sono 1
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 215151 Chiyoko - Alice's Mad Tea Party
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 215240 Ryu- - Line 4 Ruin
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 215305 3R2 - Beyond the Horizon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 216238 ginkiha - Starlight Express
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217249 Nakamura Meiko - reverb
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217557 Jubeat Ripples - Evans
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217583 void - Valedict
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217667 Wizet, Nexon - Various BGM
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217722 Mili - Fable
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217951 xi - Quietus Ray
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217952 Daft Punk - Something About Us (Love Theme from Interstella 5555)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 217956 HHHxMMxST - Oboro
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 218482 MikitoP featMatsushita - Kunoichi demo Koi ga Shitai
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 219104 Ray - sign
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 220432 ASAKA - Nanatsu Issenzakura
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 220733 NAOKI featYASMINE - INTO YOUR HEART (Ruffage Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 220802 Wakeshima Kanon - world's end, girl's rondo (Speed Up Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 222048 HHHxMMxST - Oboro
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 222073 sakuzyo - AXION
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 222946 DJ YOSHITAKA - FLOWER
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 223017 ice ft NicoNico Chorus - Theme of Puella Magi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 223697 Petit Rabbit's - Nichijou Decoration
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 224058 LiSA - Rising Hope -TV ver-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 224173 YST - The Lost Dedicated
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 224299 Martin Garrix - Animals
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 224498 Ayano Mashiro - ideal white (TV size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 225308 supercell - My Dearest (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 225779 AKINO with bless4 - EXTRA MAGIC HOUR
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 226552 Yiruma - Mika's Song (Speed Up Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 227037 M2U - Quo Vadis
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 228000 hinayukki@sigotositeP - Tsugai Kogarashi -DIVA version-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 228853 Hypernite Industries - Speedcore 300
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 230948 SUN & LUNAR (CV-Momoi Haruko & Nogawa Sakura) - Romantic summer (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 231147 Demetori - Kanjou no Matenrou ~ World's End
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 232106 NieN - OBLIVION _Rockin' Night Style_
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 232650 xi - Wish upon Twin Stars
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 233394 Ice - Entrance
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 233932 Yak_Won - Out Of The Blue
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 233979 Tomatsu Haruka - courage
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 234247 TAG - Romancing Layer
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 234526 Qrispy Joybox featmao - Umeyukiyo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 235098 u's - Snow halation (TV Size)
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 235122 Gojou Kai & Nakamura Meiko - fragment of tears
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 235126 Soleily - Violet Soul
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 235278 44teru-k remixed wa - Isetsu Higanbana Daini -Shuusei no Lycoris-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 235491 Cranky - La Campanella - Nu Rave
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 235927 Nizikawa - FKS
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 236553 Kugimiya Rie & Kitamura Eri - Holy Night
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 236684 Afilia Saga - SML
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 237212 Paitan - LEMON SUMMER
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 237512 Hommarju feat mamiko - Katayoku No Tori
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 238297 Hoshizora Rin (CVIida Riho) & Nishikino Maki (CVPile) - Beat in Angel
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 239048 Soleily - Renatus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 239471 Neru - Ningen Shikkaku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 239801 Soulja Baka - Soulja Baka
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 240415 SiM - EXiSTENCE (TV Edit)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 241103 BeautifulDay - Christmas Memories
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 241328 bbn - Identic Conflict
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 241526 Soleily - Renatus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 241815 Warak - REANIMATE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 241832 CHiCO with HoneyWorks - Sekai wa Koi ni Ochiteiru TV size
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 242159 SHK - Halloween Party
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 242368 Yooh - FIRE FIRE -DARK BLAZE REMIX-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 242484 Camellia - werewolf howls
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 243027 Various - Yolomania Vol 3A
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 243180 Garuru - Zero Gravity
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 243364 Linked Horizon - Guren no Yumiya (TV Size ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 243654 Tatsh - HEAVENLY MOON
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 244565 Fear, and Loathing in Las Vegas - Let Me Hear
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 244796 SMiLEdk - BUTTERFLY (UPSWING MIX)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 244997 alan - Over the clouds -BURST mix-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 245186 ave;new featSakura Saori - Graceful Anomaly
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 245393 Neru x Rib - Jinsei wa Hoeru
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 246059 SUWAKI - Shungiku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 246853 bbn - Identic Conflict
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 247078 NEXON-SID Sound - Smile(maplestory 8th anniversary theme song)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 247161 An - TearVid -Long mix-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 248074 Chroma - Hoshi ga Furanai Machi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 248504 Kozato - Tsuki -Yue-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 251365 Halozy - Kanshou no Matenrou
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 251951 Hana - Kuukirikigaku Shoujo to Shounen no Uta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 252179 DJAmuro - ZZ
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 252357 Memme - Chinese Restaurant
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 252901 yuikonnu - Chikyuu Saigo no Kokuhaku wo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 252947 himmeltengoku - Whisper of Rose
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 253231 Dormir - Une mage blanche
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 254581 Nightmare - Boulafacet
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 254589 senya - Tsuki ni Murakumo Hana ni Kaze
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 25461 GUMI - PANDA HERO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 255431 ginkiha - EOS -INFINITE EDIT-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 256365 Suzuki Konomi - Absolute Soul
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 256623 AKINO from bless4 - MIIRO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 257079 xi - Valhalla
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 257325 JULIE SIGTUNA (CV-Yamamoto Nozomi) - BelievexBelieve
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 257351 LiSA - BRiGHT FLiGHT
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 257607 xi - FREEDOM DiVE
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 258097 nato - Yog-Sothoth
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 258121 Yooh - Shanghai Kouchakan ~ Chinese Tea Orchid Remix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 258553 w_tre respect for AT&HU - Schur's Theorem
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 261911 MitiS & MaHi - Blu (Speed Up Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 261957 BlackY - Max Burning!!
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 263983 7!! - Bye Bye
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 264127 ETIA - Nihonshiki Koukaku-OukaRanman-
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 264749 ZOGRAPHOS (Yu_Asahina+Yamajet) - Verse IV
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 26480 JunA - The Fairy's Adventurous Tale
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 266129 Gavin G - Refresh
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 270703 Kola Kid - spaceman
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 271493 Kobaryo - Kumo No Kireme [feat kourin]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 271957 LiSA - LMiranic
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# ...
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 878429 siinamota feat Hatsune Miku - Sore wa Mahiru no Suisei (Chroma gochapon remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 87876 xi - Akasha
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 881771 DJ Noriken - #The_Relentless_(Modified)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 882461 Gesaneko - Fatima (Hard Funkot Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 882486 XX-me - escape (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 882704 Kaneko Chiharu - Final Letter
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 882805 aran - LFO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 88307 KANON NAKAGAWA starring Nao Toyama - Natsuiro Surprise
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 883669 ODDEEO + Karma Wears White Ties - Chinatown Blues [feat Megpoid Gumi]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 884240 The Flashbulb - DIDJ PVC
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 884441 a crowd of rebellion - The Crow
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 884508 aran - Back 2 Life
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 884961 Akira Complex - Ether Strike
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 884981 Kurosaki Maon - Gravitation
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 885596 Lime - Chronomia
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 885882 Camellia - Hi-technology Droppers
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 886126 Brandy - Cross Time
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 886763 ZAQ - BRAVER (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 88692 TeamGrimoire+Amaneko - croiX
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 887128 Yumeno Yuki - sign
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 887787 Iglooghost - Bug Thief
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 887810 Rhodanthe- - Jumping!! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 889405 Sakuzyo - Fracture Ray
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 889603 Nanawo Akari - One Room Sugar Life (TV Size)
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 890013 Camellia - crystallized
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 890120 Ayato x  sak x Chigusa Tajima - Beyond the BLUE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 890157 PDP - A Word To The Wise
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 890271 Endorfin - Spica
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 890491 Camellia feat Yukacco - Be Wild
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 891333 HyuN - White Aura
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 891356 HyuN - Legend of Genesis
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 892380 Laur - Absolute Domination
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 895042 R3 Music Box - Last Remote
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 895138 osu!mania 7K Dan Course - LN Dan Phase II
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 89535 sun3 - Messier 333
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 895601 AKATSUKI - Hang out!!!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 895664 AAAA - Hoshi o Kakeru Adventure ~ we are forever friends! ~ [Long ver]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 896709 you vs ETIA - Shang A Lang (kamome sano Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 897547 ZUN remixed by LeaF - Resurrection Spell
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 897754 Kobaryo - Eternal Ending (aran Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 898155 Snail's House - Magical Holiday
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 899661 ASCA - RESISTER (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 90042 Nekomata Master - Far east nightbird
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 902690 Perfume - Laser Beam
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 90270 MiddleIsland - Piano Concerto No1 Scream
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 903549 Billx - LA MD
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 90385 Igorrr - Unpleasant Sonata
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 904629 MADKID - RISE (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 905071 Luck Life - Naru (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 905599 The Flashbulb - Every Two Days
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 906073 BiSH - stereo future
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 907873 Mitsuhiko Takano - Minish Village
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 908415 MisoilePunch ~Takenoko Soe~ - FinArcDeaR Long ver
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 909582 youmi - Light in Baby Tree
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 909666 ARForest - Final Resonance
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 910428 t+pazolite - UMMU
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 910843 nora2r - New World
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 91285 Mikuriya Wata - Election Angel, Uh!
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 91301 Tamura Yukari - Fantastic future (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 913062 Camellia - potential curve
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 913114 Kotori - Nanamori (youth Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 914341 Camellia - FM Synthesis Experiment
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 914868 Wake Up, Girls! - Tachiagare! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 917698 System Of A Down - Kill Rock 'n Roll
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 917906 M2U - Mare Maris
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 919633 xi - Blue Zenith
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 919643 Minami - Kawaki Wo Ameku
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 91996 ALI PROJECT - Kyoumu Densen (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 92190 Yuuna Sasara feat Tai no Kobone - Imperishable Night 2006
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 922222 Zutto mayonaka de iinoni  - Mabusii DNA dake
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 922352 ARForest - Altros
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 922641 GARNiDELiA - Kyouki Ranbu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 923488 HyuN - Grin
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 924800 Minase Inori - Lucky Clover
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 924834 Sota Fujimori - ACCELERATE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 925376 Owsey - I've Lost All Light In My Life
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 926185 Alstroemeria Records - Bad Apple!! feat nomico (Tracy vs Astronomical Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 926703 Masayuki Suzuki - Love Dramatic feat Rikka Ihara
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 927912 KOAN Sound - Virtual Light
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 928491 Camellia - d-for the DELTA (Camellia's -PLANETARY--DUBSTEP- Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 928491 Camellia - d-for the DELTA (Camellia's PLANETARY__DUBSTEP Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 929005 Camellia - fastest crash (Camellia's ''paroxysmal'' Energetic Hitech Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 929040 Iguchi Yuka, Asumi Kana, Hikasa Yoko, Ogura Yui - Natsuiro Present (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 929112 ZAQ - Sparkling Daydream (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 929143 Camellia - Newspapers for Magicians
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 929555 SardineWhiskers - mii channel but all the pauses are uncomfortably long
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 930218 osu!mania 7K Dan Course - Regular Dan Phase III
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 930717 PSYQUI - Hysteric Night Girl feat Such (android52 Edit)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 930970 halca - Sentimental Crisis (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 931886 Amatsuki - Higurashi Moratorium
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 932214 O2i3 - Ooi
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 932307 Poppin'Party - KIZUNA MUSIC
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 932356 DJ TOTTO - Windy Fairy
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 932657 Wisp X - Eventide
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 932851 Kurokotei - wtf
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 93287 sakuzyo - Black Lair
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 933455 sheki - ari venti w- Young Citrus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 933455 sheki - ari venti w_ Young Citrus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 934627 Ben Briggs - New Game Plus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 934819 PSYQUI - Hype feat Such (lapix Remix)
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 934838 Harutya - Furaregaigirl
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 934974 Seiryu - AO-INFINITY
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 935030 ORDEN OGAN - To The End
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 936545 onumi - REGRET PART ONE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 937565 aran - LFO
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 93865 Iguchi Yuka - Grow Slowly (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 938674 Kitauji Quartet - Vivace! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 939268 Various Artists - Inverse Practice Mappack
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 939960 Suzuki Konomi - My Days
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 940363 Ska(-_-)a - Rainbow Socialism
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 940417 Kalafina - believe
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 941085 tieff - Our Story
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 942796 DJ'TEKINA--SOMETHING - Internet bitch P-Light Remix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 942796 DJ'TEKINA__SOMETHING - Internet bitch P-Light Remix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 943516 antiPLUR - Clockwork Spooks
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 94504 MuryokuP - Frozen World
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 945395 tokuP - SPiCa
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 945496 RIOT - Overkill
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 945516 LiSA - Tsumibito
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 946394 VINXIS - Three Times The Original Charm
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 946540 nanobii - astral blast
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 94670 Nogizaka46 - Yubi Bouenkyou (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 946991 Shawn Wasabi - Marble Soda
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 948734 SILENT SIREN - ODOREmotion
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 949106 Kizuna AI - AIAIAI (feat Nakata Yasutaka)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 949521 TrySail - azure (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 949646 Kola Kid - press start
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 950550 VALLEYSTONE feat KanataN - Natsuirozaka
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 952012 marsy - ACTION
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 952619 Stonebank - The Pressure
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 952639 penoreri - Prayer
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 953777 S3RL - Candy (feat Sara)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 955678 Yorushika - Deep Indigo
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 955714 PLINI X KENDRICK LAMAR - POETIC JUSTICE -- AWAY
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 95592 Y&Co feat Karin - Sweet Rain
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 95609 Remixed by DJ Command - Mermaid girl -Akiba Koubou MIX-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 95635 Bond - Wintersun (Bobby D'Ambrosio Mix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 957823 Frums - dropdead
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 957917 Hara Yumi, Amamiya Sora, Takahashi Rie, Yuuki Aoi - Isekai Girls Talk (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 958005 Enter Shikari - Rat Race
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 958159 The Frim - City Streets
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 95898 KOTOKO - agony (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 960549 Shimotsuki Haruka - Youka to Yumeutsutsu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 961186 Camellia - Towards The Horizon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 961321 Chroma - lost memory
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 96178 siromaru + cranky - Conflict (Vocaloid Ver)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 962550 in love with a ghost - flowers feat nori
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 962923 USAO - Cyaegha
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 963814 Yorushika - Hachigatsu, Bou, Tsukiakari
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 963959 Endorfin - Horizon Note
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 964453 Camellia - Sayonara Heaven (Camellia's NEKOMATAelectroRMX)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 965114 Kobaryo - Sulyvahn [feat USAO]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 965651 Fractal Dreamers - Ad Astra
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 965664 Yooh - Tribal Trial
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 965816 Kurokotei - #include -signalh-
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 965911 LiSA - Gurenge
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 966408 antiPLUR - One Life Left to Live
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 966717 Synergy Sound - Dreaming
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 967469 Dungreed Soundtrack - Frozen Time
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 967701 USAO - Extra Mode
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 96796 kors k - Flip Flap
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 968523 Roselia - Neo-Aspect
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 968574 Tsukikage - Spatto! Spy & Spyce (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 968678 Rche - Todestrieb
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 968909 Ironami - Melty Sweets
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 969195 tomppabeats - Goodmorningme
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 969976 Akiyama Uni - Kanpan Tasogare Shinbun
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 970727 tomatoism - UMP9
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 971561 antiPLUR - Runengon
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 971957 Yusuke - V (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 972451 LiSA - EGOiSTiC SHOOTER
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 974689 penoreri - Monochrome and Vivid
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 975881 ShinRa-Bansho - Mugen Shitto Gekijou 666
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 976086 TRUE - DREAM SOLISTER (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 976366 tokiwa - Memoirs feat Aitsuki Nakuru
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 978702 Kanemoto Hisako & Iwami Manaka & Ookubo Rumi - GAMERS! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 980503 Guiano - I Think I Just Died [ Cover ]
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 981053 Tatsh - Xevel
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 981117 SCRIPT - SENSE
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 981714 Imperial Circus Dead Decadence - Uta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 981805 Zutto mayonakade iinoni - Byoushin wo Kamu
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 981859 Pyxis - Koise yo Minna, Hai! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 982006 Yuuhei Satellite feat senya - Torinokosareta Bijutsu (Arranged_ HiZuMi)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 982205 Fractal Dreamers - Module_410
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 982271 Co shu Nie - ZETTAI ZETSUMEI (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 982643 mafumafu - Super Nuko ni Narenkatta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 982772 Lumen - Reincarnation by Lumen (Azure Striker Gunvolt OST)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 983271 Synergy Sound - Faraway
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 983380 Poppin'Party - KIZUNA MUSIC
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 983864 James Landino - Shiba Island
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 983953 PSYQUI - Education
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 984149 Futaba Rio (CV- Tanezaki Atsumi) - Fukashigi no Karte (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 984361 The Flashbulb - Ninedump
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 984737 Kanpyohgo - Unmei no Dark Side -Rolling Gothic mix
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 985069 Rin Kagamine - Meltdown
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 985172 BilliumMoto - life flashes before weeb eyes
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 985765 Tezuka feat Oonishi Amimi - Bokura no Jikan
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 986982 aran - Moonbound feat Yukacco (USAO Remix)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 987206 u's&Aqours - Love Live!Songs pack
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 98728 Tamura Yukari ft motsu from move - You & Me
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 987566 Hatsunetsumiko's - Libertus
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 987593 Kitamura Eri - Birth
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 988178 PSYQUI - Hype feat Such
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 989246 BilliumMoto - walking to school trippin
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 989344 supercell - Sayonara Memories
# 이미 있는 녀석이지만 큰 용량의 것을 가져왔다.
#
#
# 989512 BilliumMoto - 1xMISS
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 989858 Endorfin - Fatalism
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 992231 Yorushika - Elma
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 993792 Senko (CV- Waki Azumi), Shiro (CV- Uchida Maaya) - Koyoi mofumofu!! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 993792 Senko (CV_ Waki Azumi), Shiro (CV_ Uchida Maaya) - Koyoi mofumofu!! (TV Size)
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 994104 James Landino - Reaction feat Slyleaf
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 995539 Camellia - Clouds in the Blue
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 995694 Aimer - i-mage _in_AR_
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 996443 Frums - Credits
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 998335 Hana - Kuukirikigaku Shoujo to Shounen no Uta
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 999447 goreshit - burn this moment into the retina of my eye
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 999735 Emilia (CV- Takahashi Rie), Rem (CV- Minase Inori), Ram (CV- Murakawa Rie) - Re-latio
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 999735 Emilia (CV- Takahashi Rie), Rem (CV- Minase Inori), Ram (CV- Murakawa Rie) - Re-lation
# 이미 동일한 파일이 있으니 복사도 안하고 이름도 안바꿈.
#
# 복사 완료

# %%
word = "hellol.mp3"
print(word[-3:])
# Out:
# mp3
